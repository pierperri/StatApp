# %%
# !pip install chardet
# !pip install openpyxl
# Out:
# Requirement already satisfied: chardet in /opt/mamba/lib/python3.11/site-packages (5.2.0)
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 12.9 MB/s eta 0:00:00
# Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2

# %%
import pandas as pd
import numpy as np
import chardet
import math

# %%
file_imp_path = "data/database-imputed ESG.xlsx"
imp_data = pd.read_excel(file_imp_path)

# %%
# Variables disponibles, toutes numériques
variables = ["market_cap", "employees", "revenue", "scope_1", "scope_2", "scope_3",
                         "waste_production", "waste_recycling", "water_consumption",
                         "water_withdrawal", "energy_consumption", "hours_of_training",
                         "gender_pay_gap", "independent_board_members_percentage",
                         "legal_costs_paid_for_controversies", "ceo_compensation"]

variables_env = ["scope_1", "scope_2", "scope_3",
                "waste_production", "waste_recycling", "water_consumption",
                "water_withdrawal", "energy_consumption"]

variables_eg = ["hours_of_training","gender_pay_gap", "independent_board_members_percentage",
                "legal_costs_paid_for_controversies", "ceo_compensation"]

# Années 
annees = ["2018", "2019", "2020"]

# Regions 
regions = ["Africa / Middle East", "Asia / Pacific", "Europe", 
           "Latin America and Caribbean", "United States and Canada"]

# Secteurs 
secteurs = imp_data['primary_industry'].unique()
pd.DataFrame(secteurs).to_csv("secteur.csv")

# Nombre d'observations
nblignes = len(imp_data)

# %%
#encoding du fichier csv
#chardet.detect(open(file,'rb').read(100000))
# Out:
# {'encoding': None, 'confidence': 0.0, 'language': None}

# %%
#Importation
#data = pd.read_csv(file, encoding='Windows-1252')

# %%
imp_data
# Out:
#                                         name_year  \
# 0                                 Apple Inc._2020
# 1                                 Apple Inc._2019
# 2                                 Apple Inc._2018
# 3                  Saudi Arabian Oil Company_2020
# 4                  Saudi Arabian Oil Company_2019
# ...                                           ...
# 40549                      AB Siauliu Bankas_2019
# 40550                      AB Siauliu Bankas_2018
# 40551  Solaris Oilfield Infrastructure, Inc._2020
# 40552  Solaris Oilfield Infrastructure, Inc._2019
# 40553  Solaris Oilfield Infrastructure, Inc._2018
#
#                                  company_id  year  \
# 0      c67ee84d-5cf4-4cd0-85b9-027ad082748f  2020
# 1      c67ee84d-5cf4-4cd0-85b9-027ad082748f  2019
# 2      c67ee84d-5cf4-4cd0-85b9-027ad082748f  2018
# 3      9ea5e71e-33ac-4916-9c58-50ce9fa54abe  2020
# 4      9ea5e71e-33ac-4916-9c58-50ce9fa54abe  2019
# ...                                     ...   ...
# 40549  b68cf1bf-76ff-4d0e-b299-3fd3362b3cfc  2019
# 40550  b68cf1bf-76ff-4d0e-b299-3fd3362b3cfc  2018
# 40551  6156ea5a-64c9-4720-a374-73162114aba5  2020
# 40552  6156ea5a-64c9-4720-a374-73162114aba5  2019
# 40553  6156ea5a-64c9-4720-a374-73162114aba5  2018
#
#                                 company_name         ticker  \
# 0                                 Apple Inc.  NasdaqGS:AAPL
# 1                                 Apple Inc.  NasdaqGS:AAPL
# 2                                 Apple Inc.  NasdaqGS:AAPL
# 3                  Saudi Arabian Oil Company      SASE:2222
# 4                  Saudi Arabian Oil Company      SASE:2222
# ...                                      ...            ...
# 40549                      AB Siauliu Bankas     NSEL:SAB1L
# 40550                      AB Siauliu Bankas     NSEL:SAB1L
# 40551  Solaris Oilfield Infrastructure, Inc.       NYSE:SOI
# 40552  Solaris Oilfield Infrastructure, Inc.       NYSE:SOI
# 40553  Solaris Oilfield Infrastructure, Inc.       NYSE:SOI
#
#                    lei_cici          isin  \
# 0      HWUPKR0MPOU8FGXBT394  US0378331005
# 1      HWUPKR0MPOU8FGXBT394  US0378331005
# 2      HWUPKR0MPOU8FGXBT394  US0378331005
# 3      5586006WD91QHB7J4X50  SA14TG012N13
# 4      5586006WD91QHB7J4X50  SA14TG012N13
# ...                     ...           ...
# 40549  549300TK038P6EV4YU51  LT0000102253
# 40550  549300TK038P6EV4YU51  LT0000102253
# 40551  529900MTK3C8Y8TIIC10  US83418M1036
# 40552  529900MTK3C8Y8TIIC10  US83418M1036
# 40553  529900MTK3C8Y8TIIC10  US83418M1036
#
#                                            business_desc  \
# 0      Apple Inc. designs, manufactures, and markets ...
# 1      Apple Inc. designs, manufactures, and markets ...
# 2      Apple Inc. designs, manufactures, and markets ...
# 3      Saudi Arabian Oil Company operates as an integ...
# 4      Saudi Arabian Oil Company operates as an integ...
# ...                                                  ...
# 40549  Siauliu Bankas AB, through its subsidiaries, p...
# 40550  Siauliu Bankas AB, through its subsidiaries, p...
# 40551  Solaris Oilfield Infrastructure, Inc. designs,...
# 40552  Solaris Oilfield Infrastructure, Inc. designs,...
# 40553  Solaris Oilfield Infrastructure, Inc. designs,...
#
#                          region     hq_country  ... waste_production  \
# 0      United States and Canada  United States  ...     4.570580e+04
# 1      United States and Canada  United States  ...     5.839594e+04
# 2      United States and Canada  United States  ...     5.284984e+04
# 3          Africa / Middle East   Saudi Arabia  ...     1.704223e+08
# 4          Africa / Middle East   Saudi Arabia  ...     1.640202e+08
# ...                         ...            ...  ...              ...
# 40549                    Europe      Lithuania  ...     1.413307e+07
# 40550                    Europe      Lithuania  ...     1.411758e+07
# 40551  United States and Canada  United States  ...     3.843971e+06
# 40552  United States and Canada  United States  ...     1.418571e+07
# 40553  United States and Canada  United States  ...     1.415232e+07
#
#        waste_recycling  water_consumption  water_withdrawal  \
# 0         28939.820000       4.875000e+06      4.875000e+06
# 1         32806.410000       4.890152e+06      4.992424e+06
# 2         30104.594100       4.765152e+06      4.924242e+06
# 3         15309.000000       3.615000e+07      3.615000e+07
# 4         15309.000000       7.842800e+08      3.104395e+09
# ...                ...                ...               ...
# 40549    660760.213903       2.560251e+07      1.867752e+08
# 40550    661024.764753       2.571547e+07      1.865621e+08
# 40551    347854.460940       2.224230e+04      2.394998e+05
# 40552    658954.346979       2.545469e+07      1.891585e+08
# 40553    659663.700113       2.566359e+07      1.883780e+08
#
#        energy_consumption  hours_of_training  gender_pay_gap  \
# 0            3.019170e+06      144885.500000       13.506805
# 1            2.889680e+06      144885.500000       13.869499
# 2            2.676460e+06      144885.500000       21.097915
# 3            1.495640e+08      144885.500000       -1.690225
# 4            1.212160e+08      144885.500000       19.982123
# ...                   ...                ...             ...
# 40549        4.061208e+07      349753.237988        1.528098
# 40550        4.059737e+07      349638.709060        2.778212
# 40551        3.281263e+07      173892.822475        2.516941
# 40552        4.151777e+07      340502.372983        3.423114
# 40553        4.128384e+07      342867.646682        4.671028
#
#        independent_board_members_percentage  \
# 0                                  0.008571
# 1                                  0.008571
# 2                                  0.008750
# 3                                  0.454540
# 4                                  0.454540
# ...                                     ...
# 40549                              0.619880
# 40550                              0.615866
# 40551                              0.807719
# 40552                              0.815749
# 40553                              0.811733
#
#        legal_costs_paid_for_controversies  ceo_compensation
# 0                                0.000000      1.476926e+07
# 1                                1.850000      1.155547e+07
# 2                              920.013001      1.568222e+07
# 3                                0.000000      2.199049e+08
# 4                             1228.533586      2.015694e+07
# ...                                   ...               ...
# 40549                           31.641754      1.310021e+07
# 40550                           55.949520      1.309901e+07
# 40551                            0.000000      1.201366e+07
# 40552                           56.514497      1.309868e+07
# 40553                           80.674933      1.309859e+07
#
# [40554 rows x 27 columns]

# %%
col = data.columns
col

# %%
#Est-ce qu'il y a un NaN?
for i in col:
    print(i,"        ",any(np.array(data[i].isna())))
#Oui

# %%
#Où sont les NaN?
a,b = data['isin'],data['business_desc']
for i in range(len(a)):
    try:
        if math.isnan(a[i]):
            print('a',i, a[i])
    except:
        pass
    try:
        if math.isnan(b[i]):
            print('b',i, b[i])
    except:
        pass
